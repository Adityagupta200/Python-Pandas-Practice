# %%
import pandas as pd
from setuptools.command.build_ext import libtype

df = pd.read_csv("data/aapl.csv", parse_dates=["Date"], index_col="Date")
df.head(5)
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_7960\529222779.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("data/aapl.csv", parse_dates=["Date"], index_col="Date")
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.loc["2017-01"].Close.mean() # Mean price in january 2017
# Out:
# np.float64(119.57000000000001)

# %%
df.index = pd.to_datetime(df.index)
df = df.sort_index()
print(df.index.is_monotonic_increasing)
df.loc[pd.Timestamp("2017-01-01") : pd.Timestamp("2017-01-07")]
# Out:
# True
#               Open    High     Low   Close    Volume
# Date
# 2017-01-03  115.80  116.33  114.76  116.15  28781865
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-06  116.78  118.16  116.47  117.91  31751900

# %%
df[(df.index >= "2017-01-01") & (df.index <= "2017-01-07")]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-03  115.80  116.33  114.76  116.15  28781865
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-06  116.78  118.16  116.47  117.91  31751900

# %%
import matplotlib
df["Close"].resample("B").mean().plot()
# Out:
# <Axes: xlabel='Date'>
